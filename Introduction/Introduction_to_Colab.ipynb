# %% [markdown]
# # What is Google Colab?
# Colab is a free cloud service, and it supports free GPU!
#
# # Improve your Python programming language coding skills.
# Develop recommender systems and deep learning applications using popular libraries such as Surprise, Keras, TensorFlow, and more.
#
#
# ### Detailed information about the service can be found on the [FAQ](https://research.google.com/colaboratory/faq.html) page.

# %% [markdown]
# #You can write a new file from scratch or use files located within your google drive using Mount Drive.
# ### For this example, let's connect this Colab notebook to our google drive account.
# This connection can be very handy. We can save all our notebooks and datasets in our drive instead of uploading them per use of the Colab notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Lets see an example of how we can download a dataset from a website utilizing the wget and unzip commands.

# %% [markdown]
# Commands
# * wget command - download files from a given url
# * unzip command - unzip a file

# %%
# !wget https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# !unzip flower_data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: flower_data/train/7/image_08101.jpg
#   inflating: flower_data/train/7/image_07226.jpg
#   inflating: flower_data/train/7/image_07227.jpg
#   inflating: flower_data/train/7/image_08100.jpg
#   inflating: flower_data/train/7/image_07233.jpg
#    creating: flower_data/train/29/
#   inflating: flower_data/train/29/image_04152.jpg
#   inflating: flower_data/train/29/image_04147.jpg
#   inflating: flower_data/train/29/image_04153.jpg
#   inflating: flower_data/train/29/image_04151.jpg
#   inflating: flower_data/train/29/image_04150.jpg
#   inflating: flower_data/train/29/image_04144.jpg
#   inflating: flower_data/train/29/image_04140.jpg
#   inflating: flower_data/train/29/image_04154.jpg
#   inflating: flower_data/train/29/image_04155.jpg
#   inflating: flower_data/train/29/image_04141.jpg
#   inflating: flower_data/train/29/image_04157.jpg
#   inflating: flower_data/train/29/image_04156.jpg
# ...

# %%
# In this example, we downloaded Udacity’s flower dataset in seconds!
#Lets display an example of a flower image from our Mount drive.
from IPython.display import Image
flower_path = '/content/flower_data/train/1/image_06734.jpg'
Image(flower_path)

# %% [markdown]
# Import and install packages

# %%
# If you want to use some packages, import them.
# If a specific package does not exist, install it by using the pip install command

# %%
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import turicreate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-1b519f14fefb> in <module>()
# ----> 1 import turicreate
#
# ModuleNotFoundError: No module named 'turicreate'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Use the installation guide in the documentation of the package. https://apple.github.io/turicreate/docs/userguide/
# !pip install turicreate
# Out:
# ...
#      |████████████████████████████████| 91.9MB 103kB/s
# ...
#      |████████████████████████████████| 327kB 44.8MB/s
# ...
#      |████████████████████████████████| 86.3MB 97kB/s
# ...
#      |████████████████████████████████| 3.4MB 36.0MB/s
# ...
#      |████████████████████████████████| 3.8MB 41.0MB/s
# ...
#      |████████████████████████████████| 450kB 39.4MB/s
# ...
#   Created wheel for resampy: filename=resampy-0.2.1-cp36-none-any.whl size=320850 sha256=4c36b2869da9a6f1bf921ddd95e7b85fda867ae14ddf7d4b50c9f1aac7139213
#   Stored in directory: /root/.cache/pip/wheels/ff/4f/ed/2e6c676c23efe5394bb40ade50662e90eb46e29b48324c5f9b
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=6f7389bd1c22e0c1969b451f5d4d96afe09c41b8f2af3b9354dd946bb2f04627
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built resampy gast
# ...

# %%
# We can try to load turicreate package again.
import turicreate as tc

# %% [markdown]
# ## Code snippets
# # Colab provides some code that is used as a common practice. (i.e., Saving data to Google Drive, Upgrading Tensorflow, Visualization and more)

# %%
# For example, lets search for time series visualization

# %%
from vega_datasets import data
stocks = data.stocks()

import altair as alt
alt.Chart(stocks).mark_line().encode(
  x='date:T',
  y='price',
  color='symbol'
).interactive(bind_y=False)
# Out:
# alt.Chart(...)

# %%
# Colab allows us to organize our notebook in sections and sub-sections.

# %% [markdown]
# ## This is a header

# %% [markdown]
# ### Sub section

# %%
# Additionally, we can write formulas and explanations as follows:

# %% [markdown]
# ## This is subsection header

# %% [markdown]
# Math formula built on latex
# * $y = 0.1 x$
# * $ \frac{x^2}{e^{i\pi}}+ A_i - B_{ij} $

# %% [markdown]
# #Colab public collection

# %% [markdown]
# [google seed bank, additional information](research.google.com/seedbank/)

# %%
# To learn more about Colab, use the following link:
# colab.research.google.com

# %% [markdown]
# # Additional usefull references using colab:

# %%
# Learn how to write markdown in colab: https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd
# Getting started with google colab guide: https://towardsdatascience.com/getting-started-with-google-colab-f2fff97f594c
